# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("466-cw3image.jpg", cv2.IMREAD_GRAYSCALE)
old_parms = plt.rcParams["figure.figsize"]
plt.rcParams["figure.figsize"] = 15, 30
plt.imshow(img, "gray")
plt.show()

# %%
blur = cv2.medianBlur(img,5)
# Otsu's thresholding after Gaussian filtering
blur = cv2.GaussianBlur(blur,(5,5),0)
plt.hist(blur.ravel(),256)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c75c7caf00fb> in <module>()
# ----> 1 histog = cv2.hist(img)
#       2 plt.plot(histog)
#       3 plt.show()
#
# AttributeError: 'module' object has no attribute 'hist'
